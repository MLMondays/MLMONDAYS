# %% [markdown]
# # Advanced Binary Image Segmentation for the Geo- and Eco-sciences, using Deep Learning
#
# ## Case Study: Detecting Intertidal Reefs
#
# #### Daniel Buscombe, MARDA Science
#
# ![](https://mardascience.com/wp-content/uploads/2019/06/cropped-MardaScience_logo-5.png)

# %% [markdown]
# ## Part 6: Train a oyster reef masker using a custom learning rate scheduler and spatial dropout
#
# This jupyter notebook running on Google Colab is part of the "Advanced Binary Image Segmentation for the Geo- and Eco-sciences, using Deep Learning" course. The main course website can be accessed [here](https://mardascience.gitlab.io/binary_image_segmentation_for_geosciences/#/)
#
# In this tutorial, we will use the publicly available "drone deploy" dataset described [here](https://github.com/dronedeploy/dd-ml-segmentation-benchmark) to train a model to segment reefs from imagery. This binary semantic segmentation problem has two classes "reef" and "everything else".
#
# In the previous tutorial we made functions to read and pair image and label tiles from this data. In this tutorial, we will start by repeating that process without the visualization steps
#
# Then we will construct, train and evaluate the model. In the [oysterNet paper](https://zslpublications.onlinelibrary.wiley.com/doi/full/10.1002/rse2.134), the authors used a bigger, more sophisticated model for `instance segmentation`, that is, semantic segmentation that is aware of all the different `instances` of the class (i.e. each individual piece of reef). The model they use is called `Mask RCNN`, the implementation of which is [here](https://github.com/matterport/Mask_RCNN). That is a large and very complicated model that is hard to experiment with. The research behind the [oysterNet paper](https://zslpublications.onlinelibrary.wiley.com/doi/full/10.1002/rse2.134) is state-of-the-art.
#
# Here, we use a simpler model with fewer parameters (namely, a residual UNet) and acheive acceptable results for a semantic segmentation (predicting the masks of where the reefs are, rather than by individual instances). The UNet is the same we used in a [previous set of tutorials](https://mardascience.gitlab.io/deep_learning_landscape_classification/#/) and is relatively simple to adapt and play with to demonstrate a few principles.
#
# Actually, in this tutorial we'll start with a basic implementation and get fairly mediocre results (!)
#
# Then in the next parts, we'll adapt our training strategies and try different variations of the model, converging toward a more satisfactory result
#
# This is designed to demonstrate a problem-solving strategy, and also a principle that often applies to natural imagery:
#
# > It's not just the model you choose, it's how you train it that counts

# %% [markdown]
# ### Import libraries

# %%
import os #for accessing operating system utilities
from glob import glob #for finding files that match a certain string pattern
import matplotlib.pyplot as plt #for plotting
import numpy as np #for numerical operations
import random, string #for creating random strings
import tensorflow as tf #tensorflow
import json # for reading lable annotations in json format
import requests #for downloading files 
from PIL import Image, ImageFilter #for reading and filtering imagery
import skimage.draw #for making masks (raster label images) from label annotations
from skimage.transform import resize #for resizing imagery
from psutil import virtual_memory #for interrogating our filesystem and RAM specifications
from imageio import imwrite

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint
from random import shuffle
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, BatchNormalization
from tensorflow.keras.layers import Concatenate, Conv2DTranspose, Flatten, Activation, Add
from tensorflow.keras.models import Model

# %% [markdown]
# ### Prepare the data

# %% [markdown]
# #### Download the  imagery

# %% [markdown]
# For the remainder of the tutorials, we'll be using this version of the data, consisting of imagery and image labels, with an augmented training set consisting of double the original number of imagery, half of which have been augmented with random flips, zoms and rotations

# %%
# from https://stackoverflow.com/questions/38511444/python-download-files-from-google-drive-using-url

def download_file_from_google_drive(id, destination):
    URL = "https://docs.google.com/uc?export=download"

    session = requests.Session()

    response = session.get(URL, params = { 'id' : id }, stream = True)
    token = get_confirm_token(response)

    if token:
        params = { 'id' : id, 'confirm' : token }
        response = session.get(URL, params = params, stream = True)

    save_response_content(response, destination)    

def get_confirm_token(response):
    for key, value in response.cookies.items():
        if key.startswith('download_warning'):
            return value

    return None

def save_response_content(response, destination):
    """
    response = filename for input
    destination = filename for output
    """    
    CHUNK_SIZE = 32768

    with open(destination, "wb") as f:
        for chunk in response.iter_content(CHUNK_SIZE):
            if chunk: # filter out keep-alive new chunks
                f.write(chunk)

# %%
file_id = '19RgkzaD9w-rvAF9uBpqMONnwF0lJVPh3'
destination = 'train_images.tar.gz'
download_file_from_google_drive(file_id, destination)

# %%
# !tar -xf train_images.tar.gz > tmp.txt

# %%
file_id = '1gjWGXO7mtBhJuSOqrG6B1inzLF8TfTSX'
destination = 'val_images.tar.gz'
download_file_from_google_drive(file_id, destination)

# %%
# !tar -xf val_images.tar.gz > tmp.txt

# %%
file_id = '1x8HrgEStkBCdBmFNo1xa0x6LCVE2GE1g'
destination = 'train_labels.tar.gz'
download_file_from_google_drive(file_id, destination)

# %%
# !tar -xf train_labels.tar.gz > tmp.txt

# %%
file_id = '1v0kPgwZVQNrGAk0awJi31W83CYvHJbeX'
destination = 'val_labels.tar.gz'
download_file_from_google_drive(file_id, destination)

# %%
# !tar -xf val_labels.tar.gz > tmp.txt

# %%
root = './content/'

# %% [markdown]
# Check to see how many images we now have to work with

# %%
train_files = glob(root+"1kx1k_dataset/train_images/data/*.png")
val_files = glob(root+"1kx1k_dataset/val_images/data/*.png")

print("# train files: %i" % (len(train_files)))
print("# validation files: %i" % (len(val_files)))
# Out:
# # train files: 1054
# # validation files: 130

# %% [markdown]
# ### Setting up model training

# %% [markdown]
# #### Custom batch generator

# %% [markdown]
# We are going to feed images to the network in batches. The batch size (number of images and associated labels) will be ...

# %%
batch_size = 4

# %% [markdown]
# The next function is an image batch generator. A `generator` is a special type of python function that `yields` a set of data. In our case, it will yield a set of `batch_size` images and labels drawn randomly from the entire set of `files` provided
#
# It opens the file, reads it into a numpy array with correct dimensions checked, and then does the same for the label image. It scales the image by dividing by 255, do turn the 8-bit data scaled between 0 and 255 to data scaled between 0 and 1. The labels are flattened from 3D (RGB) to 2D (greyscale integers)

# %%
def image_batch_generator(files, sz, batch_size = 4):

  while True: # this is here because it will be called repeatedly by the training function

    #extract a random subset of files of length "batch_size"
    batch = np.random.choice(files, size = batch_size)

    #variables for collecting batches of inputs (x) and outputs (y)
    batch_x = []
    batch_y = []

    #cycle through each image in the batch
    for f in batch:

        #preprocess the raw images
        raw = Image.open(f)
        raw = raw.resize(sz)
        raw = raw.filter(ImageFilter.UnsharpMask(radius=20, percent=100))
        raw = np.array(raw)

        #check the number of channels because some of the images are RGBA or GRAY
        if len(raw.shape) == 2:
            raw = np.stack((raw,)*3, axis=-1)

        else:
            raw = raw[:,:,0:3]

        #get the image dimensions, find the min dimension, then square the image off
        nx, ny, nz = np.shape(raw)
        n = np.minimum(nx,ny)
        raw = raw[:n,:n,:]

        raw[np.isnan(raw)] = 1e-5
        raw[np.isinf(raw)] = 1e-5

        batch_x.append(raw)

        #get the masks.
        maskfile = f.replace('_images','_labels').replace('.png','.jpg')
        mask = Image.open(maskfile)
        # the mask is 3-dimensional so get the max in each channel to flatten to 2D
        try:
           mask = np.max(np.array(mask.resize(sz)),axis=2)
        except:
           mask = np.array(mask.resize(sz))

        # water pixels are always greater than 170
        mask = (mask>170).astype('int') ##170 = (2/3)*255

        mask = mask[:n,:n]

        mask[np.isnan(mask)] = 1e-5
        mask[np.isinf(mask)] = 1e-5
        batch_y.append(mask)

    #preprocess a batch of images and masks
    batch_x = np.array(batch_x) #/255. #divide image by 255 to normalize
    batch_y = np.array(batch_y)
    batch_y = np.expand_dims(batch_y,1) #add singleton dimension to batch_y

    yield (batch_x, batch_y) #yield both the image and the label together

# %%
callbacks = tf.keras.callbacks
backend = tf.keras.backend


class PlotLearning(callbacks.Callback):

    def on_train_begin(self, logs={}):
        self.i = 0
        self.x = []
        self.losses = []
        self.val_losses = []
        self.acc = []
        self.val_acc = []
        #self.fig = plt.figure()
        self.logs = []
    def on_epoch_end(self, epoch, logs={}):
        self.logs.append(logs)
        self.x.append(self.i)
        self.losses.append(logs.get('loss'))
        self.val_losses.append(logs.get('val_loss'))
        self.acc.append(logs.get('dice_coef'))
        self.val_acc.append(logs.get('val_dice_coef'))
        self.i += 1
        print('i=',self.i,'loss=',logs.get('loss'),'val_loss=',logs.get('val_loss'),'dice_coef=',logs.get('dice_coef'),'val_dice_coef=',logs.get('val_dice_coef'))

        #choose a random test image and preprocess
        f = np.random.choice(val_files)

        raw = np.array(Image.open(f).resize(sz))

        #predict the mask
        pred = 255*model.predict(np.expand_dims(raw, 0)).squeeze()
        print(np.max(pred))

        #mask post-processing
        msk  = (pred>170).astype('int') 

        msk = np.stack((msk,)*3, axis=-1)

        #show the mask and the segmented image
        combined = np.concatenate([raw, msk, raw* msk], axis = 1)
        plt.axis('off')
        plt.imshow(combined)
        plt.show()
        #plt.savefig(str(self.i)+'.png', dpi=100, bbox_inches='tight')

# %%
class LearningRateScheduler(callbacks.Callback):
    def __init__(self,
                 schedule,
                 learning_rate=None,
                 steps_per_epoch=None,
                 verbose=0):
        super(LearningRateScheduler, self).__init__()
        self.learning_rate = learning_rate
        self.schedule = schedule
        self.verbose = verbose
        self.warmup_epochs = 0 
        self.warmup_steps = 0 
        self.global_batch = 0

    def on_train_batch_begin(self, batch, logs=None):
        self.global_batch += 1
        if self.global_batch < self.warmup_steps:
            if not hasattr(self.model.optimizer, 'lr'):
                raise ValueError('Optimizer must have a "lr" attribute.')
            lr = self.learning_rate * self.global_batch / self.warmup_steps
            backend.set_value(self.model.optimizer.lr, lr)
            if self.verbose > 0:
                print('\nBatch %05d: LearningRateScheduler warming up learning '
                      'rate to %s.' % (self.global_batch, lr))

    def on_epoch_begin(self, epoch, logs=None):
        if not hasattr(self.model.optimizer, 'lr'):
            raise ValueError('Optimizer must have a "lr" attribute.')
        lr = float(backend.get_value(self.model.optimizer.lr))

        if epoch >= self.warmup_epochs:
            try:  # new API
                lr = self.schedule(epoch - self.warmup_epochs, lr)
            except TypeError:  # old API
                lr = self.schedule(epoch - self.warmup_epochs)
            if not isinstance(lr, (float, np.float32, np.float64)):
                raise ValueError('The output of the "schedule" function '
                                 'should be float.')
            backend.set_value(self.model.optimizer.lr, lr)

            if self.verbose > 0:
                print('\nEpoch %05d: LearningRateScheduler reducing learning '
                      'rate to %s.' % (epoch + 1, lr))

    def on_epoch_end(self, epoch, logs=None):
        logs = logs or {}
        logs['lr'] = backend.get_value(self.model.optimizer.lr)

# %% [markdown]
# We will specify input imagery of size `(512, 512, 3)`

# %%
sz = (512, 512)

# %% [markdown]
# #### Build the model with Dropout and a kernel initializer

# %% [markdown]
# * standard
# * spatial

# %%
def batchnorm_act(x):
    x = BatchNormalization()(x)
    return Activation("relu")(x)

# def conv_block(x, filters, kernel_size=(3, 3), padding="same", strides=1):
#     conv = batchnorm_act(x)
#     return Conv2D(filters, kernel_size, padding=padding, strides=strides)(conv)

def conv_block(x, filters, kernel_size=(3, 3), padding="same", strides=1, dropout=0.0, dropout_type="spatial"):

    if dropout_type == "spatial":
        DO = SpatialDropout2D
    elif dropout_type == "standard":
        DO = Dropout
    else:
        raise ValueError(f"dropout_type must be one of ['spatial', 'standard'], got {dropout_type}")

    conv = batchnorm_act(x)
    conv = Conv2D(filters, kernel_size, padding=padding, strides=strides, kernel_initializer='he_normal', activation='relu')(conv)

    if dropout > 0.0:
        conv = DO(dropout)(conv)

    return conv

# def bottleneck_block(x, filters, kernel_size=(3, 3), padding="same", strides=1):
#     conv = Conv2D(filters, kernel_size, padding=padding, strides=strides)(x)
#     conv = conv_block(conv, filters, kernel_size=kernel_size, padding=padding, strides=strides)
    
#     bottleneck = Conv2D(filters, kernel_size=(1, 1), padding=padding, strides=strides)(x)
#     bottleneck = batchnorm_act(bottleneck)
    
#     return Add()([conv, bottleneck])

def bottleneck_block(x, filters, kernel_size=(3, 3), padding="same", strides=1, dropout=0.0, dropout_type='spatial'):
    conv = Conv2D(filters, kernel_size, padding=padding, strides=strides, kernel_initializer='he_normal')(x)
    conv = conv_block(conv, filters, kernel_size=kernel_size, padding=padding, strides=strides, dropout=dropout, dropout_type=dropout_type)
    
    bottleneck = Conv2D(filters, kernel_size=(1, 1), padding=padding, strides=strides)(x)
    bottleneck = batchnorm_act(bottleneck)
    
    return Add()([conv, bottleneck])

# def res_block(x, filters, kernel_size=(3, 3), padding="same", strides=1):
#     res = conv_block(x, filters, kernel_size=kernel_size, padding=padding, strides=strides)
#     res = conv_block(res, filters, kernel_size=kernel_size, padding=padding, strides=1)
    
#     bottleneck = Conv2D(filters, kernel_size=(1, 1), padding=padding, strides=strides)(x)
#     bottleneck = batchnorm_act(bottleneck)
    
#     return Add()([bottleneck, res])

def res_block(x, filters, kernel_size=(3, 3), padding="same", strides=1, dropout=0.0, dropout_type='spatial'):
    res = conv_block(x, filters, kernel_size=kernel_size, padding=padding, strides=strides, dropout=dropout, dropout_type=dropout_type)
    res = conv_block(res, filters, kernel_size=kernel_size, padding=padding, strides=1, dropout=dropout, dropout_type=dropout_type)
    
    bottleneck = Conv2D(filters, kernel_size=(1, 1), padding=padding, strides=strides, kernel_initializer='he_normal')(x)
    bottleneck = batchnorm_act(bottleneck)
    
    return Add()([bottleneck, res])

def upsamp_concat_block(x, xskip):
    u = UpSampling2D((2, 2))(x)
    return Concatenate()([u, xskip])


def res_unet(sz, f, dropout=0.0, dropout_type="spatial"):

    inputs = Input(sz)

    mult = 2

    ## downsample
    e1 = bottleneck_block(inputs, f); f = int(f*mult)
    e2 = res_block(e1, f, strides=2); f = int(f*mult)
    e3 = res_block(e2, f, strides=2); f = int(f*mult)
    e4 = res_block(e3, f, strides=2); f = int(f*mult)
    _ = res_block(e4, f, strides=2)

    ## bottleneck
    b0 = conv_block(_, f, strides=1, dropout=dropout, dropout_type=dropout_type)

    _ = conv_block(b0, f, strides=1, dropout=dropout, dropout_type=dropout_type)

    ## upsample
    _ = upsamp_concat_block(_, e4)
    _ = res_block(_, f); f = int(f/mult)

    _ = upsamp_concat_block(_, e3)
    _ = res_block(_, f); f = int(f/mult)

    _ = upsamp_concat_block(_, e2)
    _ = res_block(_, f); f = int(f/mult)

    _ = upsamp_concat_block(_, e1)
    _ = res_block(_, f)

    ## classify
    outputs = Conv2D(1, (1, 1), padding="same", activation="sigmoid")(_)

    #model creation
    model = Model(inputs=[inputs], outputs=[outputs])
    return model

# %% [markdown]
# This is a class imbalanced problem, with many more `non-reef` pixels compared to `reef` pixels (the target class)
#
# So, we will use (Sorensen-)Dice loss instead of the more common IoU score (Jaccard Index) which is more suitable for class balanced problems

# %%
smooth = 1.

def dice_coef(y_true, y_pred):
    y_true_f = tf.reshape(tf.dtypes.cast(y_true, tf.float32), [-1])
    y_pred_f = tf.reshape(tf.dtypes.cast(y_pred, tf.float32), [-1])
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) + smooth)

def dice_coef_loss(y_true, y_pred):
    return 1.0 - dice_coef(y_true, y_pred)

# %% [markdown]
# Next, we make and compile our model
#
# The loss function is the Dice loss, and the metric we want to keep track of in the dice coefficient

# %%
from tensorflow.keras.layers import SpatialDropout2D, concatenate, Dropout

# %% [markdown]
# Spatial dropout randomly sets entire feature maps to 0, rather than individual pixels, which is called "standard" dropout
#
# The idea behind spatial dropout is that adjacent pixels within the receptive field of the CNN are highly correlated, so setting individual pixels to zero isn't as effective a strategy as whole feature maps, which must be "re-learned"

# %% [markdown]
# We'll try "spatial" dropout, at a rate of 5%

# %%
dropout = 0.05
dropout_type = 'spatial'

# %%
model = res_unet(sz+(3,), batch_size, dropout=dropout, dropout_type=dropout_type)
model.compile(optimizer = 'adam', loss = dice_coef_loss, metrics = [dice_coef])

# %% [markdown]
# Let's take a look at how many parameters we have to optimize

# %%
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 512, 512, 3) 0
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 512, 512, 4)  112         input_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 512, 512, 4)  16          conv2d_60[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 512, 512, 4)  16          input_3[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 512, 512, 4)  0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 512, 512, 4)  16          conv2d_62[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 512, 512, 4)  148         activation_56[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 512, 512, 4)  0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, 512, 512, 4)  0           conv2d_61[0][0]
#                                                                  activation_57[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 512, 512, 4)  16          add_18[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, 512, 512, 4)  0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 256, 256, 8)  296         activation_58[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 256, 256, 8)  40          add_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 256, 256, 8)  32          conv2d_63[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, 256, 256, 8)  32          conv2d_65[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, 256, 256, 8)  0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, 256, 256, 8)  0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 256, 256, 8)  584         activation_59[0][0]
# __________________________________________________________________________________________________
# add_19 (Add)                    (None, 256, 256, 8)  0           activation_60[0][0]
#                                                                  conv2d_64[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, 256, 256, 8)  32          add_19[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, 256, 256, 8)  0           batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 128, 128, 16) 1168        activation_61[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 128, 128, 16) 144         add_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, 128, 128, 16) 64          conv2d_66[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, 128, 128, 16) 64          conv2d_68[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, 128, 128, 16) 0           batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, 128, 128, 16) 0           batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 128, 128, 16) 2320        activation_62[0][0]
# __________________________________________________________________________________________________
# add_20 (Add)                    (None, 128, 128, 16) 0           activation_63[0][0]
#                                                                  conv2d_67[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, 128, 128, 16) 64          add_20[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 128, 128, 16) 0           batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 64, 64, 32)   4640        activation_64[0][0]
# __________________________________________________________________________________________________
# conv2d_71 (Conv2D)              (None, 64, 64, 32)   544         add_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, 64, 64, 32)   128         conv2d_69[0][0]
# __________________________________________________________________________________________________
# batch_normalization_66 (BatchNo (None, 64, 64, 32)   128         conv2d_71[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, 64, 64, 32)   0           batch_normalization_65[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, 64, 64, 32)   0           batch_normalization_66[0][0]
# __________________________________________________________________________________________________
# conv2d_70 (Conv2D)              (None, 64, 64, 32)   9248        activation_65[0][0]
# __________________________________________________________________________________________________
# add_21 (Add)                    (None, 64, 64, 32)   0           activation_66[0][0]
#                                                                  conv2d_70[0][0]
# __________________________________________________________________________________________________
# batch_normalization_67 (BatchNo (None, 64, 64, 32)   128         add_21[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, 64, 64, 32)   0           batch_normalization_67[0][0]
# __________________________________________________________________________________________________
# conv2d_72 (Conv2D)              (None, 32, 32, 64)   18496       activation_67[0][0]
# __________________________________________________________________________________________________
# conv2d_74 (Conv2D)              (None, 32, 32, 64)   2112        add_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_68 (BatchNo (None, 32, 32, 64)   256         conv2d_72[0][0]
# __________________________________________________________________________________________________
# batch_normalization_69 (BatchNo (None, 32, 32, 64)   256         conv2d_74[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, 32, 32, 64)   0           batch_normalization_68[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, 32, 32, 64)   0           batch_normalization_69[0][0]
# __________________________________________________________________________________________________
# conv2d_73 (Conv2D)              (None, 32, 32, 64)   36928       activation_68[0][0]
# __________________________________________________________________________________________________
# add_22 (Add)                    (None, 32, 32, 64)   0           activation_69[0][0]
#                                                                  conv2d_73[0][0]
# __________________________________________________________________________________________________
# batch_normalization_70 (BatchNo (None, 32, 32, 64)   256         add_22[0][0]
# __________________________________________________________________________________________________
# activation_70 (Activation)      (None, 32, 32, 64)   0           batch_normalization_70[0][0]
# __________________________________________________________________________________________________
# conv2d_75 (Conv2D)              (None, 32, 32, 64)   36928       activation_70[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_4 (SpatialDro (None, 32, 32, 64)   0           conv2d_75[0][0]
# __________________________________________________________________________________________________
# batch_normalization_71 (BatchNo (None, 32, 32, 64)   256         spatial_dropout2d_4[0][0]
# __________________________________________________________________________________________________
# activation_71 (Activation)      (None, 32, 32, 64)   0           batch_normalization_71[0][0]
# __________________________________________________________________________________________________
# conv2d_76 (Conv2D)              (None, 32, 32, 64)   36928       activation_71[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_5 (SpatialDro (None, 32, 32, 64)   0           conv2d_76[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_8 (UpSampling2D)  (None, 64, 64, 64)   0           spatial_dropout2d_5[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 64, 64, 96)   0           up_sampling2d_8[0][0]
#                                                                  add_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_72 (BatchNo (None, 64, 64, 96)   384         concatenate_8[0][0]
# __________________________________________________________________________________________________
# activation_72 (Activation)      (None, 64, 64, 96)   0           batch_normalization_72[0][0]
# __________________________________________________________________________________________________
# conv2d_77 (Conv2D)              (None, 64, 64, 64)   55360       activation_72[0][0]
# __________________________________________________________________________________________________
# conv2d_79 (Conv2D)              (None, 64, 64, 64)   6208        concatenate_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_73 (BatchNo (None, 64, 64, 64)   256         conv2d_77[0][0]
# __________________________________________________________________________________________________
# batch_normalization_74 (BatchNo (None, 64, 64, 64)   256         conv2d_79[0][0]
# __________________________________________________________________________________________________
# activation_73 (Activation)      (None, 64, 64, 64)   0           batch_normalization_73[0][0]
# __________________________________________________________________________________________________
# activation_74 (Activation)      (None, 64, 64, 64)   0           batch_normalization_74[0][0]
# __________________________________________________________________________________________________
# conv2d_78 (Conv2D)              (None, 64, 64, 64)   36928       activation_73[0][0]
# __________________________________________________________________________________________________
# add_23 (Add)                    (None, 64, 64, 64)   0           activation_74[0][0]
#                                                                  conv2d_78[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_9 (UpSampling2D)  (None, 128, 128, 64) 0           add_23[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 128, 128, 80) 0           up_sampling2d_9[0][0]
#                                                                  add_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_75 (BatchNo (None, 128, 128, 80) 320         concatenate_9[0][0]
# __________________________________________________________________________________________________
# activation_75 (Activation)      (None, 128, 128, 80) 0           batch_normalization_75[0][0]
# __________________________________________________________________________________________________
# conv2d_80 (Conv2D)              (None, 128, 128, 32) 23072       activation_75[0][0]
# __________________________________________________________________________________________________
# conv2d_82 (Conv2D)              (None, 128, 128, 32) 2592        concatenate_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_76 (BatchNo (None, 128, 128, 32) 128         conv2d_80[0][0]
# __________________________________________________________________________________________________
# batch_normalization_77 (BatchNo (None, 128, 128, 32) 128         conv2d_82[0][0]
# __________________________________________________________________________________________________
# activation_76 (Activation)      (None, 128, 128, 32) 0           batch_normalization_76[0][0]
# __________________________________________________________________________________________________
# activation_77 (Activation)      (None, 128, 128, 32) 0           batch_normalization_77[0][0]
# __________________________________________________________________________________________________
# conv2d_81 (Conv2D)              (None, 128, 128, 32) 9248        activation_76[0][0]
# __________________________________________________________________________________________________
# add_24 (Add)                    (None, 128, 128, 32) 0           activation_77[0][0]
#                                                                  conv2d_81[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_10 (UpSampling2D) (None, 256, 256, 32) 0           add_24[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 256, 256, 40) 0           up_sampling2d_10[0][0]
#                                                                  add_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_78 (BatchNo (None, 256, 256, 40) 160         concatenate_10[0][0]
# __________________________________________________________________________________________________
# activation_78 (Activation)      (None, 256, 256, 40) 0           batch_normalization_78[0][0]
# __________________________________________________________________________________________________
# conv2d_83 (Conv2D)              (None, 256, 256, 16) 5776        activation_78[0][0]
# __________________________________________________________________________________________________
# conv2d_85 (Conv2D)              (None, 256, 256, 16) 656         concatenate_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_79 (BatchNo (None, 256, 256, 16) 64          conv2d_83[0][0]
# __________________________________________________________________________________________________
# batch_normalization_80 (BatchNo (None, 256, 256, 16) 64          conv2d_85[0][0]
# __________________________________________________________________________________________________
# activation_79 (Activation)      (None, 256, 256, 16) 0           batch_normalization_79[0][0]
# __________________________________________________________________________________________________
# activation_80 (Activation)      (None, 256, 256, 16) 0           batch_normalization_80[0][0]
# __________________________________________________________________________________________________
# conv2d_84 (Conv2D)              (None, 256, 256, 16) 2320        activation_79[0][0]
# __________________________________________________________________________________________________
# add_25 (Add)                    (None, 256, 256, 16) 0           activation_80[0][0]
#                                                                  conv2d_84[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_11 (UpSampling2D) (None, 512, 512, 16) 0           add_25[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 512, 512, 20) 0           up_sampling2d_11[0][0]
#                                                                  add_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_81 (BatchNo (None, 512, 512, 20) 80          concatenate_11[0][0]
# __________________________________________________________________________________________________
# activation_81 (Activation)      (None, 512, 512, 20) 0           batch_normalization_81[0][0]
# __________________________________________________________________________________________________
# conv2d_86 (Conv2D)              (None, 512, 512, 8)  1448        activation_81[0][0]
# __________________________________________________________________________________________________
# conv2d_88 (Conv2D)              (None, 512, 512, 8)  168         concatenate_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_82 (BatchNo (None, 512, 512, 8)  32          conv2d_86[0][0]
# __________________________________________________________________________________________________
# batch_normalization_83 (BatchNo (None, 512, 512, 8)  32          conv2d_88[0][0]
# __________________________________________________________________________________________________
# activation_82 (Activation)      (None, 512, 512, 8)  0           batch_normalization_82[0][0]
# __________________________________________________________________________________________________
# activation_83 (Activation)      (None, 512, 512, 8)  0           batch_normalization_83[0][0]
# __________________________________________________________________________________________________
# conv2d_87 (Conv2D)              (None, 512, 512, 8)  584         activation_82[0][0]
# __________________________________________________________________________________________________
# add_26 (Add)                    (None, 512, 512, 8)  0           activation_83[0][0]
#                                                                  conv2d_87[0][0]
# __________________________________________________________________________________________________
# conv2d_89 (Conv2D)              (None, 512, 512, 1)  9           add_26[0][0]
# ==================================================================================================
# Total params: 298,669
# Trainable params: 296,845
# Non-trainable params: 1,824
# __________________________________________________________________________________________________

# %% [markdown]
# ### Train the model with a custom "learning rate scheduler" and Dropout

# %% [markdown]
# In Part 3 we used callback functions that adaptively change the pace of training (using an adaptive learning rate), called ["reduce loss on plateau"](https://www.tensorflow.org/api_docs/python/tf/keras/callbacks/ReduceLROnPlateau)
#
# This time we'll controll precisely the learning rate scheduler to invoke a function that describes the learning rate as a function of training epoch

# %%
def cosine_ratedecay(max_epochs, max_lr, min_lr=1e-6): 
    """
    cosine scheduler.
    :param max_epochs: max epochs
    :param max_lr: max lr
    :param min_lr: min lr
    :return: current lr
    """
    max_epochs = max_epochs ##- 5 if warmup else max_epochs

    def ratedecay(epoch):
        lrate = min_lr + (max_lr - min_lr) * (
                1 + np.cos(np.pi*6 * epoch / max_epochs)) / 2

        return lrate

    return ratedecay

# %% [markdown]
# Smaller maximum learning rate than before, and 100 epochs max

# %%
# maximum learning rate (lambda)
max_lr = 1e-4

max_epochs = 100

# %% [markdown]
# The "two bites at the cherry" learning rate scheduler

# %%
min_lr = 1e-6
def ratedecay(epoch):
    lrate = min_lr + (max_lr - min_lr) * (
            1 + np.cos(np.pi*6 * epoch / max_epochs)) / 2

    return lrate

plt.plot(ratedecay(np.arange(max_epochs)))

# %% [markdown]
# Now we have defined all these hyperparameters (parameters that we chose, not automatically determined by the model), we can make a function that builds all the various callbacks together into a list, which can then be passed to the model training (`.fit()` function)

# %%
def build_callbacks(filepath, lr_ratedecay, lr, steps_per_epoch):

    # set checkpoint file
    model_checkpoint = ModelCheckpoint(filepath, monitor='val_loss',
                                   verbose=0, save_best_only=True, mode='min',
                                   save_weights_only = True)

    # learning rate scheduler setting
    learning_rate_scheduler = LearningRateScheduler(lr_ratedecay, lr, steps_per_epoch,
                                                verbose=1)

    callbacks = [model_checkpoint, learning_rate_scheduler, PlotLearning()]

    return callbacks

# %% [markdown]
# Next, set up a name for the `.h5` file that will be used to store model weights.
#
# Finally, we train the model by calling the `.fit()` command and providing all the generators and hyperparameters defined in the callbacks
#
# The number of training and validation steps is simply the number of respective files divided by the batch size

# %%
filepath = 'reefs_weights_uresnet'+str(batch_size)+'_'+str(max_epochs)+'epochs_cosine_lrscheduler_dropout'+dropout_type+'_rate'+str(dropout)+'.h5'

train_generator = image_batch_generator(train_files, sz, batch_size = batch_size)
val_generator  = image_batch_generator(val_files, sz, batch_size = batch_size)
train_steps = len(train_files) //batch_size
val_steps = len(val_files) //batch_size
steps_per_epoch = len(train_files) // batch_size

print(train_steps)
print(val_steps)
print(steps_per_epoch)

lr_ratedecay = cosine_ratedecay(max_epochs,max_lr)
# Out:
# 263
# 32
# 263

# %% [markdown]
# If you'd rather not wait the 3-6 hours it might take to train the model you should leave the following cell uncommented

# %%
file_id = '1974PxvkDOPSWjfZTN1DoejWJStr2l6iQ'
destination = 'weights_part4.h5'
download_file_from_google_drive(file_id, destination)
model.load_weights(destination)
max_epochs = 5 #just use 5 epochs

# %% [markdown]
# Train the model

# %%
hist = model.fit(train_generator,
                epochs = max_epochs, steps_per_epoch = train_steps,
                validation_data = val_generator, validation_steps = val_steps,
                callbacks = build_callbacks(filepath,lr_ratedecay, max_lr, steps_per_epoch))
# Out:
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 1/5
# 263/263 [==============================] - ETA: 0s - loss: 0.2499 - dice_coef: 0.7501i= 1 loss= 0.24990323185920715 val_loss= 0.29793575406074524 dice_coef= 0.7500964403152466 val_dice_coef= 0.7020642161369324
# 255.0
# 263/263 [==============================] - 120s 457ms/step - loss: 0.2499 - dice_coef: 0.7501 - val_loss: 0.2979 - val_dice_coef: 0.7021 - lr: 1.0000e-04
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 9.91232189110701e-05.
# Epoch 2/5
# 263/263 [==============================] - ETA: 0s - loss: 0.2498 - dice_coef: 0.7502i= 2 loss= 0.24984529614448547 val_loss= 0.2953443229198456 dice_coef= 0.750154972076416 val_dice_coef= 0.704655647277832
# 1.2857636
# 263/263 [==============================] - 121s 459ms/step - loss: 0.2498 - dice_coef: 0.7502 - val_loss: 0.2953 - val_dice_coef: 0.7047 - lr: 9.9123e-05
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 9.652393605146844e-05.
# Epoch 3/5
# 263/263 [==============================] - ETA: 0s - loss: 0.2237 - dice_coef: 0.7763i= 3 loss= 0.22374647855758667 val_loss= 0.33950313925743103 dice_coef= 0.7762534022331238 val_dice_coef= 0.6604966521263123
# 255.0
# 263/263 [==============================] - 121s 461ms/step - loss: 0.2237 - dice_coef: 0.7763 - val_loss: 0.3395 - val_dice_coef: 0.6605 - lr: 9.6524e-05
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 9.229423231234974e-05.
# Epoch 4/5
# 263/263 [==============================] - ETA: 0s - loss: 0.2525 - dice_coef: 0.7475i= 4 loss= 0.25245776772499084 val_loss= 0.3033753037452698 dice_coef= 0.747542142868042 val_dice_coef= 0.6966245174407959
# 255.0
# 263/263 [==============================] - 120s 455ms/step - loss: 0.2525 - dice_coef: 0.7475 - val_loss: 0.3034 - val_dice_coef: 0.6966 - lr: 9.2294e-05
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 8.658394705735987e-05.
# Epoch 5/5
# 263/263 [==============================] - ETA: 0s - loss: 0.2284 - dice_coef: 0.7716i= 5 loss= 0.22837942838668823 val_loss= 0.3384556770324707 dice_coef= 0.7716206312179565 val_dice_coef= 0.6615443229675293
# 0.8931285
# 263/263 [==============================] - 120s 457ms/step - loss: 0.2284 - dice_coef: 0.7716 - val_loss: 0.3385 - val_dice_coef: 0.6615 - lr: 8.6584e-05

# %% [markdown]
# In the above, we gave an output variable to the `.fit()` command. This contains the training histories. That is, losses and metrics as a function of epoch. You can access the variables in the dictionary like so

# %%
# np.save('model4_hist.npy', hist.history)

# %%
# file_id = '1974PxvkDOPSWjfZTN1DoejWJStr2l6iQ'
# destination = 'reefs_weights_uresnet4_100epochs_cosine_lrscheduler_dropoutspatial_rate0.05.h5'

# download_file_from_google_drive(file_id, destination)

# %%
file_id = '1UK_aXEpoyzpNiUivNs8oop9JRKWqMn2h'
destination = 'model4_hist.npy'

download_file_from_google_drive(file_id, destination)

history = np.load(destination, allow_pickle=True).item()

hist = {}
hist['history'] = {}
for key in history:
   hist['history'][key] = history[key]

# %% [markdown]
# #### Plot the training history

# %%
history.keys()
# Out:
# dict_keys(['loss', 'dice_coef', 'val_loss', 'val_dice_coef', 'lr'])

# %% [markdown]
# Let's make a plot of the histories of both train and validation losses and dice coefficients, and also the history of the learning rate

# %%
plt.figure(figsize=(20,10))
plt.subplot(131)
plt.plot(hist['history']['dice_coef'], 'b', label='train Dice coefficient')
plt.plot(hist['history']['val_dice_coef'], 'k', label='validation Dice coefficient')
plt.xlabel('Epoch number'); plt.ylabel('Dice coefficent')
plt.legend()

plt.subplot(132)
plt.plot(hist['history']['loss'], 'b', label='train loss')
plt.plot(hist['history']['val_loss'], 'k', label='validation loss')
plt.xlabel('Epoch number'); plt.ylabel('Loss')
plt.legend()

plt.subplot(133)
plt.plot(hist['history']['lr'], 'g')
plt.xlabel('Epoch number'); plt.ylabel('Learning rate')
# Out:
# Text(0, 0.5, 'Learning rate')

# %% [markdown]
# ### Test the model

# %% [markdown]
# Get the test set of files and untar like we did the other sets

# %%
file_id = '1lL6cbUNhwAQsDl4P4LIYiOMOwKxrhq-c'
destination = 'test_images.tar.gz'
download_file_from_google_drive(file_id, destination)

# %%
# !tar -xf test_images.tar.gz > tmp.txt

# %%
file_id = '1GVZgjzuVatp-OjU5s5DJOgAteUvN1yDC'
destination = 'test_labels.tar.gz'
download_file_from_google_drive(file_id, destination)

# %%
# !tar -xf test_labels.tar.gz > tmp.txt

# %% [markdown]
# Get a test generator

# %%
test_files = glob(root+"1kx1k_dataset/test_images/*.png")

test_generator = image_batch_generator(test_files, sz, batch_size = batch_size)

print("# test files: %i" % (len(test_files)))
# Out:
# # test files: 163

# %% [markdown]
# Use the `.evaluate()` function of the model to get average Dice scores and losses for the test set

# %%
# some other training parameters
steps = len(test_files) // batch_size

# testing
scores = model.evaluate(test_generator, steps=steps) 

print('loss={loss:0.4f}, Mean Dice={dice_coef:0.4f}'.format(loss=scores[0], dice_coef=scores[1]))
# Out:
# 40/40 [==============================] - 13s 328ms/step - loss: 0.2955 - dice_coef: 0.7045
# loss=0.2955, Mean Dice=0.7045

# %% [markdown]
# In the [oysterNet paper](https://zslpublications.onlinelibrary.wiley.com/doi/full/10.1002/rse2.134), the authors reeport a precision of 0.771 and recall of 0.772. The Dice score is mathematically equivalent to the F1 score, the harmonic mean of precision and recall, or 77%
#
#
# Model 1 acheived an average dice score of ~62%
#
#
# This model: 70%
